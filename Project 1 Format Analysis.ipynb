# %%
import pandas as pd
import json
import csv
import os

# %%
scde_csv = "State Carbon Dioxide Emissions Data.csv"
scde = pd.read_csv(scde_csv)
scde#.head()
# Out:
#        Table 1. State emissions by year (1990 - 2017) Unnamed: 1 Unnamed: 2  \
# 0                                                 NaN        NaN        NaN
# 1               Million metric tons of carbon dioxide       1990       1991
# 2                                             Alabama        110        114
# 3                                              Alaska         34         35
# 4                                             Arizona         63         64
# 5                                            Arkansas         51         50
# 6                                          California        357        344
# 7                                            Colorado         66         67
# 8                                         Connecticut         41         40
# 9                                            Delaware         17         17
# 10                               District of Columbia          4          4
# ...

# %%
cce_csv = "cumulative-co-emissions.csv"
cce = pd.read_csv(cce_csv)
cce
# Out:
#             Entity Code  Year  Cumulative CO₂ emissions by nation (tonnes)
# 0      Afghanistan  AFG  1751                                            0
# 1      Afghanistan  AFG  1752                                            0
# 2      Afghanistan  AFG  1753                                            0
# 3      Afghanistan  AFG  1754                                            0
# 4      Afghanistan  AFG  1755                                            0
# ...            ...  ...   ...                                          ...
# 61672     Zimbabwe  ZWE  2013                                    658883535
# 61673     Zimbabwe  ZWE  2014                                    670749884
# 61674     Zimbabwe  ZWE  2015                                    681657488
# 61675     Zimbabwe  ZWE  2016                                    691590138
# 61676     Zimbabwe  ZWE  2017                                    701987856
#
# [61677 rows x 4 columns]

# %%
pim_csv = "Personal Income Monthly Reformatted.csv"
pim = pd.read_csv(pim_csv)
pim
# Out:
#                                            Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                                                 NaN        NaN        NaN
# 1                                                 NaN        NaN        NaN
# 2                                                 NaN        NaN        NaN
# 3                                                 NaN       1959       1959
# 4                                                 NaN        JAN        FEB
# 5                                     Personal income      391.8      393.7
# 6                           Compensation of employees        278      279.3
# 7                                  Wages and salaries      252.3      253.6
# 8                                  Private industries      206.8      208.2
# 9                                          Government       45.5       45.4
# 10                  Supplements to wages and salaries       25.7       25.7
# ...

# %%
pcgdp_csv = "Percent Change in GDP Reformatted.csv"
psgdp = pd.read_csv(pcgdp_csv)
psgdp
# Out:
#                                            Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                                                 NaN        NaN        NaN
# 1                                                 NaN        NaN        NaN
# 2                                                 NaN        NaN        NaN
# 3                                                 NaN       1990       1991
# 4                                                 NaN        NaN        NaN
# 5                              Gross domestic product        3.8        3.4
# 6                   Personal consumption expenditures        4.4        3.3
# 7                                               Goods        4.1        2.4
# 8                                       Durable goods          1        1.5
# 9                                    Nondurable goods        5.7        2.9
# 10                                           Services        4.6        3.9
# ...
